# %% [markdown]
# # A background elimination method based on linear programming for Raman spectra
#
# In this notebook we are trying to reproduce the background elimination technique described in the article of Sung-June Baek, Aaron Park, Aigou Shen, Jiming Hu: https://doi.org/10.1016/j.chemolab.2009.04.007.

# %% [markdown]
# ### Settings and functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy.optimize import linprog
# %matplotlib inline
font = {'size': 15}

# %%
def raman_plot():
    """
    Funzione che serve per settare la dimensione dell'immgine e i label degli assi per un plot di spettro Raman.
    """
    plt.figure(figsize=(16,6))
    plt.xlabel(r"Raman shift [$cm^{-1}$]",fontsize=18)
    plt.ylabel("Intensity [a.u.]",fontsize=18)

# %%
def define_names(r=11,c=11):
    """
    Funzione che definisce i nomi delle coordinate degli spettri sul sample. I nomi sono del tipo r1c1,r1c2, ecc.
    Come default usa 11 colonne e 11 righe. Il primo nome è wn, che sta per wave number.
    """
    #definisco i nomi da assegnare ai punti delli spettri di sampling
    #wn -> wave number  r -> row c -> columns
    names = ['wn']+[f'r{k}c{i}' for k in range(1,r+1) for i in range(1,c+1)]
    return names

# %%
def interpol(S):
    min = int(S[0][0]) if S[0][0]==0 else int(S[0][0]) +1
    max = int(S[0][-1])
    X = np.arange(min,max+1,1)
    S = np.array([X, np.interp(X,S[0],S[1])])
    return S

# %%
def _raman_labels():
    plt.figure(figsize=(10,5))
    plt.xlabel(r'Raman shift [$cm^{-1}$]')
    plt.ylabel('Counts')

def plot(S):
    S = type2spectra(S)
    _raman_labels()
    if type(S)!=list:
        plt.plot(S[0], S[1])
    else:
        for s in S:
            plt.plot(s[0], s[1], label='')
    plt.show(block=False)

# %% [markdown]
# ## Import of some test spectra
# Here we import a few spectra on which to test this background-elimination technique. Then we chose one among these in the variable *col* on which the procedure is performed, change that variable to change the test-spectrum.

# %%
#definisco i nomi delle colonne da dare 
names=define_names()
#quì importiamo i dati dei sampling in dataframes pandas, la colonna dei numeri d'onda è una unica per tutti
data = pd.read_csv('./data/S1_mapA_11x11.txt', delim_whitespace=True, names=names)

# %% [markdown]
# # The procedure

# %% [markdown]
# The first step is the spectrum interpolation. This is something we do for each used spectrum just for simplicity. As can be seen from the plot there is absolutely no differences in the shape of the original spectrum and the interpolated one.

# %%
col= 'r5c7'  #'r5c2'
S =np.array(data[['wn',col]].copy()).transpose()
S=S[:,0:1200]
#S=S[:,1300:]
raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()

# %% [markdown]
# ## Noise removal
# Apply Savitzky–Golay ﬁlter with span $L_n$ to the given spectrum. The degree of a polynomial is set to 2. In the following, $s$ denotes the noise removed data. It doesn't matter if the peaks are distorted since we are interested in the background.

# %%
#############################################################################################
L_n=51                                       #lenght of smoothing filter for noise removal  #
pol_degree=2                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,pol_degree)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %% [markdown]
# # Polynomial fitting with constrains => Linear programming
# 1. devo mantenere lo spettro non troppo largo, altrimenti numericamente non si riesce a trovare una soluzione!

# %%
p= 11   # polinomial order
edge_width = 20 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
# vector/matrice Y and X
Y = S_smooth[1]
x = S_smooth[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
x = S[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])


raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -510878.4068417549
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  82

# %% [markdown]
# ## We have to perform this on different sections of the spectra

# %%
S=S # SIGNAL
# 1) the signal must be already smoothed!
# 2) the signal must not be too large!

p= 11   # polinomial order
edge_width = 10 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
def bkg_fit(S, p, edge_width=20, edge_weight=2, plot=False, verbose=False):
    # vector/matrice Y and X
    Y = S[1]
    x = S[0]
    x = (x-x[0])/(x[-1]-x[0])
    X = np.zeros((len(x),p))
    for i in range(p):
        X[:, i] = x**i

    # vector C
    H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
    C = - np.dot(H,X)

    # solving the linear programming problem
    res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
    W = res['x']
    stat = res['status']
    if verbose == True:
        print('sum(Y-XW) = ', res['fun'])
        print('status = ', res['status'])
        print('message = ', res['message'])
        print('# of iter = ', res['nit'])

    if stat==0:    
        # generate the BKG
        x = S[0]
        x = (x-x[0])/(x[-1]-x[0])
        X = np.zeros((len(x),p))
        for i in range(p):
            X[:, i] = x**i
        BKG = np.dot(X,W)

        if plot==True:
            raman_plot()
            plt.plot(S[0], BKG, label='Estimated background')
            plt.plot(S[0],S[1], label='Original signal')
    
        return np.array([S[0],BKG]), stat
    else:
        return 0, stat

# example: BKG, stat = bkg_fit(S_smooth, 11, edge_width=20, edge_weight=2, plot=True)

def bkg_full_fit(S, p=11, edge_width=20, edge_weight=2, L_n=41, plot=False):
    # SMOOTHING
    S_smooth = S.copy()
    S_smooth[1]=savgol_filter(S[1],L_n,2)

    if plot==True:
        plt.figure(figsize=(16,6))
        plt.xlabel("sample",fontsize=18)
        plt.ylabel("Intensity [some unit]",fontsize=18)
        plt.plot(S[0],S[1], label='Original signal')
        plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
    
    # SEGMENTED FIT
    length = S_smooth.shape[1]
    bounds = []
    i=0
    while i<length:
        if i+1100<=length:
            i+=1100
            bounds.append([i-1100,i])
            i-=200
        else:
            i+=1100  
            bounds.append([length-1100,length])
    
    BKG=[]
    for i in bounds:
        BKG_temp, stat = bkg_fit(S_smooth[:,i[0]:i[1]], p, edge_width, edge_weight)
        if stat != 0:
            print('Fit do not converged, try smaller p!')
            return
        BKG.append(BKG_temp)

    if plot==True:
        #raman_plot()
        for i in BKG:
            plt.plot(i[0], i[1])
        plt.plot(S[0],S[1])

    #L'UNIONE SI PUO RIFARE SICURAMENTE IN MODO PIU PULITO
    BKG_final=BKG[0][:,0:1100-edge_width]
    for i in BKG[1:-1]:
        BKG_final = np.append(BKG_final,i[:,edge_width:-edge_width],axis=1)
        
    last = length%(len(bounds)-1)+200-edge_width
    BKG_final = np.append(BKG_final,BKG[-1][:,last:],axis=1)

    sorted_index = BKG_final[0].argsort()
    BKG_final = np.array([np.take_along_axis(BKG_final[0], sorted_index, axis=0),np.take_along_axis(BKG_final[1], sorted_index, axis=0)]) 

    BKG_final[1]=savgol_filter(BKG_final[1],L_n,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*2+1,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*3,2)

    #si puo fare sicuramente piu pulito
    BKG_final = np.array([np.unique(BKG_final[0]), np.interp(np.unique(BKG_final[0]), BKG_final[0], BKG_final[1])])
    
    if plot==True:
        plt.plot(BKG_final[0],BKG_final[1],label='Estimated background')
        plt.legend()

    return BKG_final

# %%
col= 'r4c3'
#'r5c7'  
#'r5c2' bello
#'r1c3' brutto ma comunque dai
S =np.array(data[['wn',col]].copy()).transpose()
S=interpol(S)
S=S
BKG=bkg_full_fit(S, p=10, edge_width=50, edge_weight=2, L_n=41, plot=True)

raman_plot()
plt.plot(S[0],S[1]-BKG[1])

# %% [markdown]
# # Gaussian Kernel
# Let's try to use gaussian functions instead of polynomial functions.

# %%
col= 'r3c5'#'r1c5'  #'r5c2'
S =np.array(data[['wn',col]].copy()).transpose()
raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()
#############################################################################################
L_n=31                                      #lenght of smoothing filter for noise removal  #                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,1)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %%
# GENERATIVE FUNCTION
p= 100   # number of Gaussians
sigma = 150
edge_width = 1 # this is for the edge problem of fitting
edge_weight = 1

#############################################################
# matrice X
X = np.zeros((len(S_smooth[0]),p))

for i in enumerate(np.linspace(S_smooth[0,0]-sigma,S_smooth[0,-1]+sigma,p)):
   X[:, i[0]] = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-(S_smooth[0]-i[1])**(2)/(2*sigma**2))

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = S_smooth[1],bounds = (-1e6, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])
XX = np.arange(200,1000)

plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*sigma**2))),label='Kernel function')
# SUBTRACTION
raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -1558306.4977151847
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  364

# %%
plt.plot(W,'o')

# %% [markdown]
# ## Write the above as a function

# %%
# GENERATIVE FUNCTION
def bkg_via_gauss(S, L_n, sigma, p, edge_width=1, edge_weight=1, plot=False):
   
   # smoothing
   S_smooth = S.copy()
   S_smooth[1]=savgol_filter(S[1],L_n,2)

   # matrice X
   X = np.zeros((len(S_smooth[0]),p))

   for i in enumerate(np.linspace(S_smooth[0,0]-sigma,S_smooth[0,-1]+sigma,p)):
      X[:, i[0]] = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-(S_smooth[0]-i[1])**(2)/(2*sigma**2))
   
   # vector C
   H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
   C = - np.dot(H,X)

   # solving the linear programming problem
   res = linprog(C, A_ub=X, b_ub = S_smooth[1], bounds = (-1e6, None), method='highs-ds')
   W = res['x']
   status = res['status'] # status = 0 means OK
   print('sum(Y-XW) = ', res['fun'])
   print('message = ', res['message'])
   print('# of iter = ', res['nit'])

   if status!=0:
      print('Fit failed !!!')
      return
   # generate the BKG

   BKG = np.array([S_smooth[0], np.dot(X,W)])
   S_nobkg = S.copy()
   S_nobkg[1] -= BKG[1]

   if plot==True:
      _raman_labels()
      plt.plot(BKG[0],BKG[1], label='Estimated background')
      plt.plot(S[0],S[1], label='Original signal')
      plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
      XX = np.arange(200,1000)
      plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*sigma**2))),label='Kernel function')
      plt.legend()
      plt.show()
   return S_nobkg, BKG

# %%
col= 'r1c5' #'r3c9'  #'r5c2'
S = np.array(data[['wn',col]].copy()).transpose()
S = interpol(S)

S_nobkg, BKG = bkg_via_gauss(S=S, L_n=31, sigma=180, p=200, edge_width=10, edge_weight=5, plot=True)

_raman_labels()
plt.plot(S_nobkg[0],S_nobkg[1])
# Out:
# sum(Y-XW) =  -1537919.8707379657
# message =  Optimization terminated successfully.
# # of iter =  644

# %% [markdown]
# # TEST

# %%
S_nobkg150, BKG150 = bkg_via_gauss(S=S, L_n=31, sigma=150, p=100)
S_nobkg100, BKG100 = bkg_via_gauss(S=S, L_n=31, sigma=100, p=100)
S_nobkg200, BKG200 = bkg_via_gauss(S=S, L_n=31, sigma=200, p=100)
_raman_labels()
plt.plot(S[0],S[1])
plt.plot(BKG150[0],BKG150[1], label='150')
plt.plot(BKG200[0],BKG200[1], label='200')
plt.plot(BKG100[0],BKG100[1], label='100')
plt.legend()
# Out:
# sum(Y-XW) =  -1516430.4219849675
# message =  Optimization terminated successfully.
# # of iter =  322
# sum(Y-XW) =  -1520120.4016787854
# message =  Optimization terminated successfully.
# # of iter =  395
# sum(Y-XW) =  -1514986.527921659
# message =  Optimization terminated successfully.
# # of iter =  244

# %% [markdown]
# # Let's see lots of samples

# %%
plt.figure(figsize=(10,5))
plt.xlabel(r'Raman shift [$cm^{-1}$]')
plt.ylabel('Counts')

for i in range(11):
    for j in range(11):
        col= 'r'+str(i+1)+'c'+str(j+1)
        S = np.array(data[['wn',col]].copy()).transpose()
        S = interpol(S)

        S_nobkg, BKG = bkg_via_gauss(S=S,L_n=21,sigma=150,p=100,plot=False)

        for k in range(len(S_nobkg[1])):
            if S_nobkg[1][k]<0:
                S_nobkg[1][k]=0

        plt.plot(S_nobkg[0],S_nobkg[1])
        #plt.xlim(0,1700)
# Out:
# sum(Y-XW) =  -558944.99148664
# message =  Optimization terminated successfully.
# # of iter =  354
# sum(Y-XW) =  -1473020.7096154916
# message =  Optimization terminated successfully.
# # of iter =  361
# sum(Y-XW) =  -574704.1539636822
# message =  Optimization terminated successfully.
# # of iter =  384
# sum(Y-XW) =  -637435.0955602431
# message =  Optimization terminated successfully.
# # of iter =  348
# sum(Y-XW) =  -1515131.3503271982
# message =  Optimization terminated successfully.
# # of iter =  343
# sum(Y-XW) =  -628249.1553868481
# message =  Optimization terminated successfully.
# # of iter =  362
# sum(Y-XW) =  -891829.5198176284
# message =  Optimization terminated successfully.
# # of iter =  353
# sum(Y-XW) =  -550242.4648306349
# message =  Optimization terminated successfully.
# # of iter =  420
# sum(Y-XW) =  -750049.2120964096
# message =  Optimization terminated successfully.
# # of iter =  362
# sum(Y-XW) =  -439185.44071481226
# message =  Optimization terminated successfully.
# # of iter =  440
# sum(Y-XW) =  -678359.9541486648
# message =  Optimization terminated successfully.
# # of iter =  342
# sum(Y-XW) =  -654669.6368275824
# message =  Optimization terminated successfully.
# # of iter =  367
# sum(Y-XW) =  -801534.8374693373
# message =  Optimization terminated successfully.
# # of iter =  357
# sum(Y-XW) =  -651327.1840355748
# message =  Optimization terminated successfully.
# # of iter =  365
# sum(Y-XW) =  -933974.6570715511
# message =  Optimization terminated successfully.
# # of iter =  355
# sum(Y-XW) =  -2139365.2452760898
# message =  Optimization terminated successfully.
# # of iter =  356
# sum(Y-XW) =  -421708.0200060886
# message =  Optimization terminated successfully.
# # of iter =  377
# sum(Y-XW) =  -984956.7823944797
# message =  Optimization terminated successfully.
# # of iter =  364
# sum(Y-XW) =  -535675.6159904047
# message =  Optimization terminated successfully.
# # of iter =  379
# sum(Y-XW) =  -663351.5325507815
# message =  Optimization terminated successfully.
# # of iter =  348
# sum(Y-XW) =  -434456.4269035692
# message =  Optimization terminated successfully.
# # of iter =  372
# sum(Y-XW) =  -1085232.637006251
# message =  Optimization terminated successfully.
# # of iter =  314
# sum(Y-XW) =  -381893.90160013555
# message =  Optimization terminated successfully.
# # of iter =  358
# sum(Y-XW) =  -966707.3093841986
# message =  Optimization terminated successfully.
# # of iter =  371
# sum(Y-XW) =  -602640.2001600785
# message =  Optimization terminated successfully.
# # of iter =  388
# sum(Y-XW) =  -629811.3960146884
# message =  Optimization terminated successfully.
# # of iter =  353
# sum(Y-XW) =  -1554366.9325968598
# message =  Optimization terminated successfully.
# # of iter =  390
# sum(Y-XW) =  -607770.2677155149
# message =  Optimization terminated successfully.
# # of iter =  371
# sum(Y-XW) =  -2137982.0694732843
# message =  Optimization terminated successfully.
# # of iter =  370
# sum(Y-XW) =  -661551.2308970898
# message =  Optimization terminated successfully.
# # of iter =  372
# sum(Y-XW) =  -459085.15155547374
# message =  Optimization terminated successfully.
# # of iter =  406
# sum(Y-XW) =  -900422.2822396667
# message =  Optimization terminated successfully.
# # of iter =  358
# sum(Y-XW) =  -13392250.473998198
# message =  Optimization terminated successfully.
# # of iter =  339
# sum(Y-XW) =  -483155.0027415136
# message =  Optimization terminated successfully.
# # of iter =  398
# sum(Y-XW) =  -7046152.409232345
# message =  Optimization terminated successfully.
# # of iter =  329
# sum(Y-XW) =  -1066704.488314647
# message =  Optimization terminated successfully.
# # of iter =  355
# sum(Y-XW) =  -487511.03174436913
# message =  Optimization terminated successfully.
# # of iter =  356
# sum(Y-XW) =  -537411.0487039615
# message =  Optimization terminated successfully.
# # of iter =  404
# sum(Y-XW) =  -752748.6942517066
# message =  Optimization terminated successfully.
# # of iter =  337
# sum(Y-XW) =  -477184.2232729698
# message =  Optimization terminated successfully.
# # of iter =  384
# sum(Y-XW) =  -492189.6402666986
# message =  Optimization terminated successfully.
# # of iter =  366
# sum(Y-XW) =  -4974174.205651886
# message =  Optimization terminated successfully.
# # of iter =  281
# sum(Y-XW) =  -554222.402478663
# message =  Optimization terminated successfully.
# # of iter =  357
# sum(Y-XW) =  -755592.9329395329
# message =  Optimization terminated successfully.
# # of iter =  354
# sum(Y-XW) =  -1090981.7841708043
# message =  Optimization terminated successfully.
# # of iter =  351
# sum(Y-XW) =  -8890657.529005071
# message =  Optimization terminated successfully.
# # of iter =  349
# sum(Y-XW) =  -1312235.06369863
# message =  Optimization terminated successfully.
# # of iter =  409
# sum(Y-XW) =  -10061051.16609446
# message =  Optimization terminated successfully.
# # of iter =  315
# sum(Y-XW) =  -770536.0746293694
# message =  Optimization terminated successfully.
# # of iter =  341
# sum(Y-XW) =  -681808.2267643267
# message =  Optimization terminated successfully.
# # of iter =  340
# sum(Y-XW) =  -973118.5602212993
# message =  Optimization terminated successfully.
# # of iter =  347
# sum(Y-XW) =  -756293.8920988382
# message =  Optimization terminated successfully.
# # of iter =  370
# sum(Y-XW) =  -1663322.8871006458
# message =  Optimization terminated successfully.
# # of iter =  325
# sum(Y-XW) =  -662570.9171098934
# message =  Optimization terminated successfully.
# # of iter =  368
# sum(Y-XW) =  -450449.093770423
# message =  Optimization terminated successfully.
# # of iter =  367
# sum(Y-XW) =  -977901.8841194434
# message =  Optimization terminated successfully.
# # of iter =  355
# sum(Y-XW) =  -940898.0496813131
# message =  Optimization terminated successfully.
# # of iter =  346
# sum(Y-XW) =  -1327003.7048908153
# message =  Optimization terminated successfully.
# # of iter =  341
# sum(Y-XW) =  -530291.6496324639
# message =  Optimization terminated successfully.
# # of iter =  366
# sum(Y-XW) =  -549518.297315059
# message =  Optimization terminated successfully.
# # of iter =  406
# sum(Y-XW) =  -645898.9341405274
# message =  Optimization terminated successfully.
# # of iter =  385
# sum(Y-XW) =  -630282.0724973136
# message =  Optimization terminated successfully.
# # of iter =  352
# sum(Y-XW) =  -1359604.025027988
# message =  Optimization terminated successfully.
# # of iter =  397
# sum(Y-XW) =  -709542.8196414281
# message =  Optimization terminated successfully.
# # of iter =  354
# sum(Y-XW) =  -411183.8878524602
# message =  Optimization terminated successfully.
# # of iter =  379
# sum(Y-XW) =  -1144902.702613849
# message =  Optimization terminated successfully.
# # of iter =  342
# sum(Y-XW) =  -1196471.7456165606
# message =  Optimization terminated successfully.
# # of iter =  374
# sum(Y-XW) =  -1117735.062244726
# message =  Optimization terminated successfully.
# # of iter =  353
# sum(Y-XW) =  -596495.9300426312
# message =  Optimization terminated successfully.
# # of iter =  340
# sum(Y-XW) =  -804254.6016624921
# message =  Optimization terminated successfully.
# # of iter =  347
# sum(Y-XW) =  -405672.4387615864
# message =  Optimization terminated successfully.
# # of iter =  372
# sum(Y-XW) =  -1332925.8873346557
# message =  Optimization terminated successfully.
# # of iter =  331
# sum(Y-XW) =  -433745.25570314104
# message =  Optimization terminated successfully.
# # of iter =  391
# sum(Y-XW) =  -498611.50948847533
# message =  Optimization terminated successfully.
# # of iter =  409
# sum(Y-XW) =  -1190886.3653624111
# message =  Optimization terminated successfully.
# # of iter =  328
# sum(Y-XW) =  -1189486.070451766
# message =  Optimization terminated successfully.
# # of iter =  300
# sum(Y-XW) =  -1432906.4340053159
# message =  Optimization terminated successfully.
# # of iter =  419
# sum(Y-XW) =  -510696.86292736983
# message =  Optimization terminated successfully.
# # of iter =  398
# sum(Y-XW) =  -602303.1572832481
# message =  Optimization terminated successfully.
# # of iter =  371
# sum(Y-XW) =  -510383.48850778193
# message =  Optimization terminated successfully.
# # of iter =  379
# sum(Y-XW) =  -593795.8970269612
# message =  Optimization terminated successfully.
# # of iter =  360
# sum(Y-XW) =  -1801848.1683081172
# message =  Optimization terminated successfully.
# # of iter =  400
# sum(Y-XW) =  -818496.8267878552
# message =  Optimization terminated successfully.
# # of iter =  330
# sum(Y-XW) =  -558225.6834577844
# message =  Optimization terminated successfully.
# # of iter =  420
# sum(Y-XW) =  -2041241.9749632035
# message =  Optimization terminated successfully.
# # of iter =  382
# sum(Y-XW) =  -989074.9155647832
# message =  Optimization terminated successfully.
# # of iter =  415
# sum(Y-XW) =  -1857388.0419540026
# message =  Optimization terminated successfully.
# # of iter =  369
# sum(Y-XW) =  -4801857.570859577
# message =  Optimization terminated successfully.
# # of iter =  314
# sum(Y-XW) =  -503910.1432468275
# message =  Optimization terminated successfully.
# # of iter =  383
# sum(Y-XW) =  -1995955.45744129
# message =  Optimization terminated successfully.
# # of iter =  341
# sum(Y-XW) =  -705330.0011533871
# message =  Optimization terminated successfully.
# # of iter =  393
# sum(Y-XW) =  -1351730.4971704145
# message =  Optimization terminated successfully.
# # of iter =  385
# sum(Y-XW) =  -3135817.5753744985
# message =  Optimization terminated successfully.
# # of iter =  347
# sum(Y-XW) =  -969951.7918060028
# message =  Optimization terminated successfully.
# # of iter =  347
# sum(Y-XW) =  -737509.4732920507
# message =  Optimization terminated successfully.
# # of iter =  342
# sum(Y-XW) =  -1237982.1219610588
# message =  Optimization terminated successfully.
# # of iter =  343
# sum(Y-XW) =  -733540.8272261599
# message =  Optimization terminated successfully.
# # of iter =  304
# sum(Y-XW) =  -1311228.8255642594
# message =  Optimization terminated successfully.
# # of iter =  348
# sum(Y-XW) =  -1503518.3286616486
# message =  Optimization terminated successfully.
# # of iter =  325
# sum(Y-XW) =  -869182.2955847902
# message =  Optimization terminated successfully.
# # of iter =  298
# sum(Y-XW) =  -793541.2165430204
# message =  Optimization terminated successfully.
# # of iter =  356
# sum(Y-XW) =  -920203.3511353398
# message =  Optimization terminated successfully.
# # of iter =  319
# sum(Y-XW) =  -1499477.7177051667
# message =  Optimization terminated successfully.
# # of iter =  305
# sum(Y-XW) =  -938370.0585620867
# message =  Optimization terminated successfully.
# # of iter =  366
# sum(Y-XW) =  -4719529.28229563
# message =  Optimization terminated successfully.
# # of iter =  318
# sum(Y-XW) =  -2582094.492905556
# message =  Optimization terminated successfully.
# # of iter =  373
# sum(Y-XW) =  -539445.7392419248
# message =  Optimization terminated successfully.
# # of iter =  373
# sum(Y-XW) =  -514977.45059105
# message =  Optimization terminated successfully.
# # of iter =  382
# sum(Y-XW) =  -542234.7411436083
# message =  Optimization terminated successfully.
# # of iter =  335
# sum(Y-XW) =  -2356265.2502476694
# message =  Optimization terminated successfully.
# # of iter =  357
# sum(Y-XW) =  -390585.3278599885
# message =  Optimization terminated successfully.
# # of iter =  354
# sum(Y-XW) =  -560095.160283515
# message =  Optimization terminated successfully.
# # of iter =  367
# sum(Y-XW) =  -1835883.544392702
# message =  Optimization terminated successfully.
# # of iter =  326
# sum(Y-XW) =  -790531.135626314
# message =  Optimization terminated successfully.
# # of iter =  351
# sum(Y-XW) =  -791687.7458727111
# message =  Optimization terminated successfully.
# # of iter =  375
# sum(Y-XW) =  -651731.3424469566
# message =  Optimization terminated successfully.
# # of iter =  381
# sum(Y-XW) =  -1179579.9179745924
# message =  Optimization terminated successfully.
# # of iter =  398
# sum(Y-XW) =  -2376109.5896045426
# message =  Optimization terminated successfully.
# # of iter =  368
# sum(Y-XW) =  -2834351.5118791186
# message =  Optimization terminated successfully.
# # of iter =  314
# sum(Y-XW) =  -14201794.440499412
# message =  Optimization terminated successfully.
# # of iter =  306
# sum(Y-XW) =  -424822.6311835191
# message =  Optimization terminated successfully.
# # of iter =  348
