# %% [markdown]
# # A background elimination method based on linear programming for Raman spectra
#
# In this notebook we are trying to reproduce the background elimination technique described in the article of Sung-June Baek, Aaron Park, Aigou Shen, Jiming Hu: https://doi.org/10.1016/j.chemolab.2009.04.007.

# %% [markdown]
# ### Settings and functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy.optimize import linprog
# %matplotlib inline
font = {'size': 15}

# %%
def raman_plot():
    """
    Funzione che serve per settare la dimensione dell'immgine e i label degli assi per un plot di spettro Raman.
    """
    plt.figure(figsize=(16,6))
    plt.xlabel(r"Raman shift [$cm^{-1}$]",fontsize=18)
    plt.ylabel("Intensity [a.u.]",fontsize=18)

# %%
def define_names(r=11,c=11):
    """
    Funzione che definisce i nomi delle coordinate degli spettri sul sample. I nomi sono del tipo r1c1,r1c2, ecc.
    Come default usa 11 colonne e 11 righe. Il primo nome è wn, che sta per wave number.
    """
    #definisco i nomi da assegnare ai punti delli spettri di sampling
    #wn -> wave number  r -> row c -> columns
    names = ['wn']+[f'r{k}c{i}' for k in range(1,r+1) for i in range(1,c+1)]
    return names

# %%
def interpol(S):
    min = int(S[0][0]) if S[0][0]==0 else int(S[0][0]) +1
    max = int(S[0][-1])
    X = np.arange(min,max+1,1)
    S = np.array([X, np.interp(X,S[0],S[1])])
    return S

# %%
def _raman_labels():
    plt.figure(figsize=(10,5))
    plt.xlabel(r'Raman shift [$cm^{-1}$]')
    plt.ylabel('Counts')

def plot(S):
    S = type2spectra(S)
    _raman_labels()
    if type(S)!=list:
        plt.plot(S[0], S[1])
    else:
        for s in S:
            plt.plot(s[0], s[1], label='')
    plt.show(block=False)

# %% [markdown]
# ## Import of some test spectra
# Here we import a few spectra on which to test this background-elimination technique. Then we chose one among these in the variable *col* on which the procedure is performed, change that variable to change the test-spectrum.

# %%
# open txt file with numpy array
n=11

temp = np.loadtxt('./data/S1_mapA_11x11.txt')
wn = temp[:,0]
data = np.zeros((n,n,len(wn)))
for i in range(n):
    for j in range(n):
        data[i,j,:] = temp[:,1+i*n+j]

# %% [markdown]
# # The procedure

# %% [markdown]
# The first step is the spectrum interpolation. This is something we do for each used spectrum just for simplicity. As can be seen from the plot there is absolutely no differences in the shape of the original spectrum and the interpolated one.

# %%
S = np.array([wn,data[10,10]])

raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()

# %% [markdown]
# ## Noise removal
# Apply Savitzky–Golay ﬁlter with span $L_n$ to the given spectrum. The degree of a polynomial is set to 2. In the following, $s$ denotes the noise removed data. It doesn't matter if the peaks are distorted since we are interested in the background.

# %%
#############################################################################################
L_n=51                                       #lenght of smoothing filter for noise removal  #
pol_degree=2                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,pol_degree)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %% [markdown]
# # Polynomial fitting with constrains => Linear programming
# 1. devo mantenere lo spettro non troppo largo, altrimenti numericamente non si riesce a trovare una soluzione!

# %%
p= 11   # polinomial order
edge_width = 20 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
# vector/matrice Y and X
Y = S_smooth[1]
x = S_smooth[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
x = S[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])


raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -423021.3430069089
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  79

# %% [markdown]
# ## We have to perform this on different sections of the spectra

# %%
S=S # SIGNAL
# 1) the signal must be already smoothed!
# 2) the signal must not be too large!

p= 11   # polinomial order
edge_width = 10 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
def bkg_fit(S, p, edge_width=20, edge_weight=2, plot=False, verbose=False):
    # vector/matrice Y and X
    Y = S[1]
    x = S[0]
    x = (x-x[0])/(x[-1]-x[0])
    X = np.zeros((len(x),p))
    for i in range(p):
        X[:, i] = x**i

    # vector C
    H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
    C = - np.dot(H,X)

    # solving the linear programming problem
    res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
    W = res['x']
    stat = res['status']
    if verbose == True:
        print('sum(Y-XW) = ', res['fun'])
        print('status = ', res['status'])
        print('message = ', res['message'])
        print('# of iter = ', res['nit'])

    if stat==0:    
        # generate the BKG
        x = S[0]
        x = (x-x[0])/(x[-1]-x[0])
        X = np.zeros((len(x),p))
        for i in range(p):
            X[:, i] = x**i
        BKG = np.dot(X,W)

        if plot==True:
            raman_plot()
            plt.plot(S[0], BKG, label='Estimated background')
            plt.plot(S[0],S[1], label='Original signal')
    
        return np.array([S[0],BKG]), stat
    else:
        return 0, stat

# example: BKG, stat = bkg_fit(S_smooth, 11, edge_width=20, edge_weight=2, plot=True)

def bkg_full_fit(S, p=11, edge_width=20, edge_weight=2, L_n=41, plot=False):
    # SMOOTHING
    S_smooth = S.copy()
    S_smooth[1]=savgol_filter(S[1],L_n,2)

    if plot==True:
        plt.figure(figsize=(16,6))
        plt.xlabel("sample",fontsize=18)
        plt.ylabel("Intensity [some unit]",fontsize=18)
        plt.plot(S[0],S[1], label='Original signal')
        plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
    
    # SEGMENTED FIT
    length = S_smooth.shape[1]
    bounds = []
    i=0
    while i<length:
        if i+1100<=length:
            i+=1100
            bounds.append([i-1100,i])
            i-=200
        else:
            i+=1100  
            bounds.append([length-1100,length])
    
    BKG=[]
    for i in bounds:
        BKG_temp, stat = bkg_fit(S_smooth[:,i[0]:i[1]], p, edge_width, edge_weight)
        if stat != 0:
            print('Fit do not converged, try smaller p!')
            return
        BKG.append(BKG_temp)

    if plot==True:
        #raman_plot()
        for i in BKG:
            plt.plot(i[0], i[1])
        plt.plot(S[0],S[1])

    #L'UNIONE SI PUO RIFARE SICURAMENTE IN MODO PIU PULITO
    BKG_final=BKG[0][:,0:1100-edge_width]
    for i in BKG[1:-1]:
        BKG_final = np.append(BKG_final,i[:,edge_width:-edge_width],axis=1)
        
    last = length%(len(bounds)-1)+200-edge_width
    BKG_final = np.append(BKG_final,BKG[-1][:,last:],axis=1)

    sorted_index = BKG_final[0].argsort()
    BKG_final = np.array([np.take_along_axis(BKG_final[0], sorted_index, axis=0),np.take_along_axis(BKG_final[1], sorted_index, axis=0)]) 

    BKG_final[1]=savgol_filter(BKG_final[1],L_n,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*2+1,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*3,2)

    #si puo fare sicuramente piu pulito
    BKG_final = np.array([np.unique(BKG_final[0]), np.interp(np.unique(BKG_final[0]), BKG_final[0], BKG_final[1])])
    
    if plot==True:
        plt.plot(BKG_final[0],BKG_final[1],label='Estimated background')
        plt.legend()

    return BKG_final

# %%
#col= 'r4c3'
#'r5c7'  
#'r5c2' bello
#'r1c3' brutto ma comunque dai
S = np.array([wn,data[5,2]])

S=interpol(S)
S=S
BKG=bkg_full_fit(S, p=10, edge_width=50, edge_weight=2, L_n=41, plot=True)

raman_plot()
plt.plot(S[0],S[1]-BKG[1])

# %% [markdown]
# # Gaussian Kernel
# Let's try to use gaussian functions instead of polynomial functions.

# %%
S = np.array([wn,data[10,10]])

S[1] = S[1]/np.max(S[1])
raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()
#############################################################################################
L_n=21                                      #lenght of smoothing filter for noise removal  #                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,1)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %%
# GENERATIVE FUNCTION
p= 100   # number of Gaussians
sigma = 130
edge_width = 1 # this is for the edge problem of fitting
edge_weight = 1

#############################################################
# matrice X
X = np.zeros((len(S_smooth[0]),p))

for i in enumerate(np.linspace(S_smooth[0,0]-sigma,S_smooth[0,-1]+sigma,p)):
   X[:, i[0]] = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-(S_smooth[0]-i[1])**(2)/(2*sigma**2))

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = S_smooth[1],bounds = (0, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])
XX = np.arange(200,1000)

plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*sigma**2))),label='Kernel function')
# SUBTRACTION
raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -1646.497716332316
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  266

# %%
plt.plot(W,'o')

# %% [markdown]
# ## Write the above as a function

# %%
# GENERATIVE FUNCTION
def bkg_via_gauss(S, L_n, sigma, p, edge_width=1, edge_weight=1, plot=False):
   
   # smoothing
   S_smooth = S.copy()
   S_smooth[1]=savgol_filter(S[1],L_n,2)

   # matrice X
   X = np.zeros((len(S_smooth[0]),p))

   for i in enumerate(np.linspace(S_smooth[0,0]-sigma,S_smooth[0,-1]+sigma,p)):
      X[:, i[0]] = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-(S_smooth[0]-i[1])**(2)/(2*sigma**2))
   
   # vector C
   H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
   C = - np.dot(H,X)

   # solving the linear programming problem
   res = linprog(C, A_ub=X, b_ub = S_smooth[1], bounds = (0, None), method='highs-ds')
   W = res['x']
   status = res['status'] # status = 0 means OK
   print('sum(Y-XW) = ', res['fun'])
   print('message = ', res['message'])
   print('# of iter = ', res['nit'])

   if status!=0:
      print('Fit failed !!!')
      return
   # generate the BKG

   BKG = np.array([S_smooth[0], np.dot(X,W)])
   S_nobkg = S.copy()
   S_nobkg[1] -= BKG[1]

   if plot==True:
      _raman_labels()
      plt.plot(BKG[0],BKG[1], label='Estimated background')
      plt.plot(S[0],S[1], label='Original signal')
      plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
      XX = np.arange(200,1000)
      plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*sigma**2))),label='Kernel function')
      plt.legend()
      plt.show()
   return S_nobkg, BKG

# %%
S = np.array([wn,data[10,10]])
S = interpol(S)

S_nobkg, BKG = bkg_via_gauss(S=S, L_n=31, sigma=180, p=200, edge_width=10, edge_weight=5, plot=True)

_raman_labels()
plt.plot(S_nobkg[0],S_nobkg[1])
# Out:
# sum(Y-XW) =  -1536015.0716575575
# message =  Optimization terminated successfully.
# # of iter =  437

# %% [markdown]
# # TEST

# %%
S_nobkg150, BKG150 = bkg_via_gauss(S=S, L_n=31, sigma=150, p=100)
S_nobkg100, BKG100 = bkg_via_gauss(S=S, L_n=31, sigma=100, p=100)
S_nobkg200, BKG200 = bkg_via_gauss(S=S, L_n=31, sigma=200, p=100)
_raman_labels()
plt.plot(S[0],S[1])
plt.plot(BKG150[0],BKG150[1], label='150')
plt.plot(BKG200[0],BKG200[1], label='200')
plt.plot(BKG100[0],BKG100[1], label='100')
plt.legend()
# Out:
# sum(Y-XW) =  -1515184.9576742689
# message =  Optimization terminated successfully.
# # of iter =  255
# sum(Y-XW) =  -1517551.440702681
# message =  Optimization terminated successfully.
# # of iter =  299
# sum(Y-XW) =  -1512150.5030244284
# message =  Optimization terminated successfully.
# # of iter =  165

# %% [markdown]
# # Let's see lots of samples

# %%
plt.figure(figsize=(10,5))
plt.xlabel(r'Raman shift [$cm^{-1}$]')
plt.ylabel('Counts')

for i in range(11):
    for j in range(11):
        
        S = np.array([wn,data[i,j]])
        
        S_nobkg, BKG = bkg_via_gauss(S=S,L_n=21,sigma=150,p=100,plot=False)

        for k in range(len(S_nobkg[1])):
            if S_nobkg[1][k]<0:
                S_nobkg[1][k]=0

        plt.plot(S_nobkg[0],S_nobkg[1])
        #plt.xlim(0,1700)
# Out:
# sum(Y-XW) =  -386197.29584741674
# message =  Optimization terminated successfully.
# # of iter =  238
# sum(Y-XW) =  -1017601.3398702703
# message =  Optimization terminated successfully.
# # of iter =  234
# sum(Y-XW) =  -395323.9425094225
# message =  Optimization terminated successfully.
# # of iter =  221
# sum(Y-XW) =  -440240.09236971504
# message =  Optimization terminated successfully.
# # of iter =  218
# sum(Y-XW) =  -1047644.9032472653
# message =  Optimization terminated successfully.
# # of iter =  241
# sum(Y-XW) =  -433692.3975134666
# message =  Optimization terminated successfully.
# # of iter =  223
# sum(Y-XW) =  -615793.1324783012
# message =  Optimization terminated successfully.
# # of iter =  248
# sum(Y-XW) =  -380428.8832663415
# message =  Optimization terminated successfully.
# # of iter =  215
# sum(Y-XW) =  -517880.73792987596
# message =  Optimization terminated successfully.
# # of iter =  259
# sum(Y-XW) =  -302904.44824847084
# message =  Optimization terminated successfully.
# # of iter =  214
# sum(Y-XW) =  -468657.14416792645
# message =  Optimization terminated successfully.
# # of iter =  247
# sum(Y-XW) =  -451849.39857405866
# message =  Optimization terminated successfully.
# # of iter =  231
# sum(Y-XW) =  -554168.4047609036
# message =  Optimization terminated successfully.
# # of iter =  244
# sum(Y-XW) =  -450256.09627278417
# message =  Optimization terminated successfully.
# # of iter =  224
# sum(Y-XW) =  -644936.5670479361
# message =  Optimization terminated successfully.
# # of iter =  251
# sum(Y-XW) =  -1478535.2355651667
# message =  Optimization terminated successfully.
# # of iter =  235
# sum(Y-XW) =  -291056.5515902105
# message =  Optimization terminated successfully.
# # of iter =  271
# sum(Y-XW) =  -680646.6439729767
# message =  Optimization terminated successfully.
# # of iter =  252
# sum(Y-XW) =  -370301.0742395777
# message =  Optimization terminated successfully.
# # of iter =  223
# sum(Y-XW) =  -458659.44318972767
# message =  Optimization terminated successfully.
# # of iter =  223
# sum(Y-XW) =  -299673.8587386574
# message =  Optimization terminated successfully.
# # of iter =  212
# sum(Y-XW) =  -749346.0287575423
# message =  Optimization terminated successfully.
# # of iter =  283
# sum(Y-XW) =  -263865.35359689395
# message =  Optimization terminated successfully.
# # of iter =  215
# sum(Y-XW) =  -668284.6943680963
# message =  Optimization terminated successfully.
# # of iter =  237
# sum(Y-XW) =  -415317.59865863936
# message =  Optimization terminated successfully.
# # of iter =  242
# sum(Y-XW) =  -434732.6879910753
# message =  Optimization terminated successfully.
# # of iter =  224
# sum(Y-XW) =  -1073636.6438993863
# message =  Optimization terminated successfully.
# # of iter =  207
# sum(Y-XW) =  -419670.8696070108
# message =  Optimization terminated successfully.
# # of iter =  250
# sum(Y-XW) =  -1478563.8381898948
# message =  Optimization terminated successfully.
# # of iter =  232
# sum(Y-XW) =  -457061.33750698756
# message =  Optimization terminated successfully.
# # of iter =  246
# sum(Y-XW) =  -317429.55857010576
# message =  Optimization terminated successfully.
# # of iter =  242
# sum(Y-XW) =  -620847.7990870606
# message =  Optimization terminated successfully.
# # of iter =  212
# sum(Y-XW) =  -9255815.291114707
# message =  Optimization terminated successfully.
# # of iter =  283
# sum(Y-XW) =  -333334.53783202317
# message =  Optimization terminated successfully.
# # of iter =  214
# sum(Y-XW) =  -4870453.428409812
# message =  Optimization terminated successfully.
# # of iter =  269
# sum(Y-XW) =  -736527.5566763568
# message =  Optimization terminated successfully.
# # of iter =  262
# sum(Y-XW) =  -336811.3850144579
# message =  Optimization terminated successfully.
# # of iter =  222
# sum(Y-XW) =  -371371.4144303304
# message =  Optimization terminated successfully.
# # of iter =  228
# sum(Y-XW) =  -519283.8246817643
# message =  Optimization terminated successfully.
# # of iter =  236
# sum(Y-XW) =  -329699.00233589014
# message =  Optimization terminated successfully.
# # of iter =  267
# sum(Y-XW) =  -340124.22219332546
# message =  Optimization terminated successfully.
# # of iter =  233
# sum(Y-XW) =  -3438579.944086154
# message =  Optimization terminated successfully.
# # of iter =  285
# sum(Y-XW) =  -382617.04824868764
# message =  Optimization terminated successfully.
# # of iter =  272
# sum(Y-XW) =  -522106.28265409224
# message =  Optimization terminated successfully.
# # of iter =  253
# sum(Y-XW) =  -754033.4886471732
# message =  Optimization terminated successfully.
# # of iter =  213
# sum(Y-XW) =  -6147615.855725214
# message =  Optimization terminated successfully.
# # of iter =  290
# sum(Y-XW) =  -905991.5241494207
# message =  Optimization terminated successfully.
# # of iter =  232
# sum(Y-XW) =  -6954659.026100897
# message =  Optimization terminated successfully.
# # of iter =  279
# sum(Y-XW) =  -532060.2187875685
# message =  Optimization terminated successfully.
# # of iter =  218
# sum(Y-XW) =  -470563.70101045637
# message =  Optimization terminated successfully.
# # of iter =  211
# sum(Y-XW) =  -672429.1776371094
# message =  Optimization terminated successfully.
# # of iter =  263
# sum(Y-XW) =  -521294.2168020066
# message =  Optimization terminated successfully.
# # of iter =  231
# sum(Y-XW) =  -1149346.0509888076
# message =  Optimization terminated successfully.
# # of iter =  261
# sum(Y-XW) =  -457635.63962968613
# message =  Optimization terminated successfully.
# # of iter =  231
# sum(Y-XW) =  -310805.7211627021
# message =  Optimization terminated successfully.
# # of iter =  247
# sum(Y-XW) =  -675243.3034734562
# message =  Optimization terminated successfully.
# # of iter =  238
# sum(Y-XW) =  -650328.5039680249
# message =  Optimization terminated successfully.
# # of iter =  233
# sum(Y-XW) =  -916524.437462195
# message =  Optimization terminated successfully.
# # of iter =  243
# sum(Y-XW) =  -364935.41166020546
# message =  Optimization terminated successfully.
# # of iter =  207
# sum(Y-XW) =  -380091.92883765313
# message =  Optimization terminated successfully.
# # of iter =  243
# sum(Y-XW) =  -446424.9149263203
# message =  Optimization terminated successfully.
# # of iter =  247
# sum(Y-XW) =  -434760.82943331375
# message =  Optimization terminated successfully.
# # of iter =  198
# sum(Y-XW) =  -939875.6259583627
# message =  Optimization terminated successfully.
# # of iter =  261
# sum(Y-XW) =  -489559.2422946537
# message =  Optimization terminated successfully.
# # of iter =  252
# sum(Y-XW) =  -284376.4687115867
# message =  Optimization terminated successfully.
# # of iter =  220
# sum(Y-XW) =  -791277.2112188978
# message =  Optimization terminated successfully.
# # of iter =  260
# sum(Y-XW) =  -825741.7282158406
# message =  Optimization terminated successfully.
# # of iter =  224
# sum(Y-XW) =  -773368.8195915105
# message =  Optimization terminated successfully.
# # of iter =  268
# sum(Y-XW) =  -412137.5221330863
# message =  Optimization terminated successfully.
# # of iter =  227
# sum(Y-XW) =  -554574.7794589663
# message =  Optimization terminated successfully.
# # of iter =  226
# sum(Y-XW) =  -280428.0795837686
# message =  Optimization terminated successfully.
# # of iter =  213
# sum(Y-XW) =  -920531.6327257401
# message =  Optimization terminated successfully.
# # of iter =  229
# sum(Y-XW) =  -299809.44014065387
# message =  Optimization terminated successfully.
# # of iter =  233
# sum(Y-XW) =  -344625.8390344624
# message =  Optimization terminated successfully.
# # of iter =  224
# sum(Y-XW) =  -822939.0898980205
# message =  Optimization terminated successfully.
# # of iter =  231
# sum(Y-XW) =  -821343.6966554156
# message =  Optimization terminated successfully.
# # of iter =  207
# sum(Y-XW) =  -990412.9559184749
# message =  Optimization terminated successfully.
# # of iter =  239
# sum(Y-XW) =  -353095.89285432256
# message =  Optimization terminated successfully.
# # of iter =  218
# sum(Y-XW) =  -416102.52664950636
# message =  Optimization terminated successfully.
# # of iter =  246
# sum(Y-XW) =  -352085.71279789874
# message =  Optimization terminated successfully.
# # of iter =  208
# sum(Y-XW) =  -410166.5672114436
# message =  Optimization terminated successfully.
# # of iter =  230
# sum(Y-XW) =  -1245548.586011974
# message =  Optimization terminated successfully.
# # of iter =  247
# sum(Y-XW) =  -565643.2241987754
# message =  Optimization terminated successfully.
# # of iter =  220
# sum(Y-XW) =  -385967.96959890396
# message =  Optimization terminated successfully.
# # of iter =  237
# sum(Y-XW) =  -1410755.8003497527
# message =  Optimization terminated successfully.
# # of iter =  279
# sum(Y-XW) =  -683614.8784202043
# message =  Optimization terminated successfully.
# # of iter =  247
# sum(Y-XW) =  -1283447.00543115
# message =  Optimization terminated successfully.
# # of iter =  261
# sum(Y-XW) =  -3318943.929965999
# message =  Optimization terminated successfully.
# # of iter =  236
# sum(Y-XW) =  -347587.73903487873
# message =  Optimization terminated successfully.
# # of iter =  210
# sum(Y-XW) =  -1379969.0513021357
# message =  Optimization terminated successfully.
# # of iter =  221
# sum(Y-XW) =  -487009.6356252009
# message =  Optimization terminated successfully.
# # of iter =  224
# sum(Y-XW) =  -934287.4178943353
# message =  Optimization terminated successfully.
# # of iter =  215
# sum(Y-XW) =  -2167541.795202395
# message =  Optimization terminated successfully.
# # of iter =  260
# sum(Y-XW) =  -670077.4571503517
# message =  Optimization terminated successfully.
# # of iter =  258
# sum(Y-XW) =  -509997.6768561442
# message =  Optimization terminated successfully.
# # of iter =  259
# sum(Y-XW) =  -854827.6320232183
# message =  Optimization terminated successfully.
# # of iter =  221
# sum(Y-XW) =  -507157.15588865057
# message =  Optimization terminated successfully.
# # of iter =  280
# sum(Y-XW) =  -906821.0311700589
# message =  Optimization terminated successfully.
# # of iter =  273
# sum(Y-XW) =  -1038834.0340916931
# message =  Optimization terminated successfully.
# # of iter =  220
# sum(Y-XW) =  -598676.8547977948
# message =  Optimization terminated successfully.
# # of iter =  236
# sum(Y-XW) =  -548057.4349678579
# message =  Optimization terminated successfully.
# # of iter =  242
# sum(Y-XW) =  -636025.1840866288
# message =  Optimization terminated successfully.
# # of iter =  220
# sum(Y-XW) =  -1036474.0925579683
# message =  Optimization terminated successfully.
# # of iter =  254
# sum(Y-XW) =  -648754.2919686324
# message =  Optimization terminated successfully.
# # of iter =  305
# sum(Y-XW) =  -3261669.4500181004
# message =  Optimization terminated successfully.
# # of iter =  242
# sum(Y-XW) =  -1784565.5926816433
# message =  Optimization terminated successfully.
# # of iter =  264
# sum(Y-XW) =  -372384.6928910121
# message =  Optimization terminated successfully.
# # of iter =  230
# sum(Y-XW) =  -355867.04022867075
# message =  Optimization terminated successfully.
# # of iter =  219
# sum(Y-XW) =  -374268.4093641456
# message =  Optimization terminated successfully.
# # of iter =  246
# sum(Y-XW) =  -1629653.5151010305
# message =  Optimization terminated successfully.
# # of iter =  265
# sum(Y-XW) =  -270322.3826417644
# message =  Optimization terminated successfully.
# # of iter =  275
# sum(Y-XW) =  -386685.1717362418
# message =  Optimization terminated successfully.
# # of iter =  237
# sum(Y-XW) =  -1269110.2019659376
# message =  Optimization terminated successfully.
# # of iter =  261
# sum(Y-XW) =  -545853.083259451
# message =  Optimization terminated successfully.
# # of iter =  226
# sum(Y-XW) =  -546391.1259057536
# message =  Optimization terminated successfully.
# # of iter =  238
# sum(Y-XW) =  -449676.8290071133
# message =  Optimization terminated successfully.
# # of iter =  249
# sum(Y-XW) =  -815403.7234067131
# message =  Optimization terminated successfully.
# # of iter =  202
# sum(Y-XW) =  -1642541.152115789
# message =  Optimization terminated successfully.
# # of iter =  244
# sum(Y-XW) =  -1957270.6983293493
# message =  Optimization terminated successfully.
# # of iter =  265
# sum(Y-XW) =  -9821477.739338193
# message =  Optimization terminated successfully.
# # of iter =  271
# sum(Y-XW) =  -293304.29227326444
# message =  Optimization terminated successfully.
# # of iter =  259
